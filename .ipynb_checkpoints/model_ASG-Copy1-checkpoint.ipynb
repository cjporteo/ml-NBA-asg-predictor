# %% [markdown]
# # NBA All-Star Classifier - Modelling

# %% [markdown]
# ## Outlier Addressing and Preprocessing

# %%
# data manipulation/visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# modelling and blackbox analysis
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import BorderlineSMOTE
from xgboost import XGBClassifier as XGBC
import shap
from pdpbox import pdp

# classification metrics
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score, log_loss, plot_confusion_matrix

# basic utils
import os.path
import pickle

from IPython.display import display

pd.options.mode.chained_assignment = None  # default='warn'

# check if this is our first time running the script
# if the model exists from a prior execution, we can load the model from memory instead of retraining it from scratch
already_trained = os.path.exists('./ASG_predictor.model')

# directory to store plots concerning model evaluation and interpretation
if not os.path.exists('./Plots'):
    os.makedirs('./Plots')

# labeled dataset
df_train = pd.read_csv('ASG_train.csv')

# current year's dataset (unlabeled)
df_to_predict = pd.read_csv('ASG_to_predict.csv')

# pull out the current season from the df for file naming purposes
prediction_year = df_to_predict.loc[0, 'Year'] + 1

# save the PLAYER and TEAM columns for later
# these features get dropped during the prediction process but we will add them back in later
names_and_teams = df_to_predict[['PLAYER', 'TEAM']]

# manually purging some outliers that are polluting the training data
# (since the dataset is small and our SME is high, this can be done manually - otherwise
# we would perform some automated method like Tukey outlier detection)
#
# these players fall into either one or both of the follwing two cases:
#   A: had long, illustrious careers and were selected in their twilight years as a sort of "farewell",
#      despite not playing at an All-Star level
#   B: sat out way too many games of this season and were only selected due to overpowering clout/fan 
#      favouritism
#
# Note: 'Year' in our dataset refers to the calandar year in which the season started, so the ASG in question 
#       will be equal to 'Year'+1
outliers = set([
    ('Dirk Nowitzki', 2018), # A: Dirk's selection in the 2019 ASG was very much a "respect" pick - career tribute
    ('Kobe Bryant', 2015), # A
    ('Kobe Bryant', 2013), # A/B
    ('Yao Ming', 2010), # B: had all of China rallying for him despite playing in only 5 out of a possible 44 games (11.3%)
    ('Allen Iverson', 2009), # A
    ('Allen Iverson', 2008), # A
    ("Shaquille O'Neal", 2006), # A/B
    ('Ray Allen', 2003), # B
    ('Jamaal Magloire', 2003), # infamously questionable pick
    ('Vince Carter', 2002), # B
    ('Grant Hill', 2000), # B
    ('Anfernee Hardaway', 1997), #A/B
    ('Anfernee Hardaway', 1996) #A/B
])

# stores the indices of our outliers
outlier_indices = []

# gather outlier indices
def process_outliers(row):
    if (row['PLAYER'], row['Year']) in outliers:
        outlier_indices.append(row.name)

# reject the outliers
df_train[['PLAYER', 'Year']].apply(process_outliers, axis=1)
df_train.drop(outlier_indices, inplace=True)

for df in [df_train, df_to_predict]:
    # drop any player who appeared in less than 7 games 
    df.drop(df[df['GP'] < 7].index, inplace=True)

    # the % of team's games the player played in
    # sometimes because of scheduling/trades, a player's indiviual GP may exceed their current team's, so we impose a ceiling of 1
    df['Play Pct.'] = (df['GP'] / df['Team GP']).map(lambda pct : min(pct, 1))

    # nomalized via league average pace for that year
    for col in ['PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV', '3PM']:
        df['Adjusted ' + col] = df[col] / df['Avg. Pace']

# final features used for this model
#
# features that have been commented out indicated negligible predictive power in earlier models
# and have been stripped in the final version
features = [
    'Adjusted PTS',
    'Adjusted REB',
    'Adjusted AST',
    #'Adjusted STL',
    'Adjusted BLK',
    #'Adjusted TOV',
    #'Adjusted 3PM',
    'DEFWS',
    #'TS%',
    #'USG%',
    'PIE',
    'Play Pct.',
    'Team Conference Rank',
    'Prior ASG Appearances',
    #'AS Last Year?'
]

feature_short_labels = [
    'PTS',
    'REB',
    'AST',
    #'STL',
    'BLK',
    #'TOV',
    #'3PM',
    'DEFWS',
    #'TS%',
    #'USG%',
    'PIE',
    'Play%',
    'Team',
    "ASG's",
    #'AS Last Yr.'
]

# %% [markdown]
# ## Partitioning Labeled Dataset

# %%
# split labeled data into 66% train, 17% validation, 17% test
train, test = train_test_split(df_train, train_size=0.66, stratify=df_train['Selected?'], shuffle=True, random_state=0)
#validation, test = train_test_split(non_train, train_size=0.5, stratify=non_train['Selected?'], shuffle=True, random_state=0)

X, y = train[features], train['Selected?']
X_test, y_test = test[features], test['Selected?']

df_to_predict = df_to_predict[features]

tuned_model = None

# %% [markdown]
# ## Tuning XGBoost Hyperparameters

# %%
# performed only during first execution for model tuning purposes - trains the model
already_trained=False
if not already_trained:
    
    skf = StratifiedKFold(n_splits=4, shuffle=True, random_state=0)
    
    # range of learning rates we will consider
    learning_rates = [a * (10**b) for b in range(-6, -1) for a in range(1, 10)] + [0.1]
    
    # maximum number of rounds we will consider
    max_n_estimators = 2500
    # number of rounds after which to terminate the process if no improvement is seen
    early_stopping_rounds = 10
    # maximum depth of the decision tree - kept very low to avoid overfitting and ensure a relatively "simple" model
    max_depth = 2
    
    best_learning_rate, best_ntree_limit = learning_rates[0], 1
    
    highest_auc = -float('inf')
    
    for learning_rate in learning_rates:
        
        auc_scores = []
    
        for train_index, val_index in skf.split(X, y):
            X_train, y_train = X.iloc[train_index], y.iloc[train_index]
            X_val, y_val = X.iloc[val_index], y.iloc[val_index]

            #print(y_train.value_counts())
            #
            # we use SMOTE (synthetic minority oversampling technique) to balance out our output classes
            #
            # in our training data, there are 5409 non all-stars and only 368 all-stars, so a crude blanket strategy labelling
            # everyone as a non-all star would still achieve 93.6% accuracy
            #
            # SMOTE will create synthetic data points in the all-star class so that the classes are balanced
            X_train_oversampled, y_train_oversampled = BorderlineSMOTE(random_state=0).fit_sample(X_train, y_train)

            model = XGBC(objective='binary:logistic', learning_rate=learning_rate,
                         n_estimators=max_n_estimators, max_depth=max_depth, n_jobs=-1, random_state=0)
            model.fit(X=X_train_oversampled, y=y_train_oversampled, eval_metric=['auc'],
                      eval_set=[(X_train_oversampled, y_train_oversampled), (X_val, y_val)],
                      early_stopping_rounds=early_stopping_rounds, verbose=True)
            curr_auc = max(model.evals_result()['validation_1']['auc']) # AUC of the validation set
            auc_scores.append(curr_auc)
        
        avg_auc_score = np.mean(auc_scores)
        
        if avg_auc_score > highest_auc:
            highest_auc, best_learning_rate, best_ntree_limit = avg_auc_score, learning_rate, model.best_ntree_limit

    # train the model with the optimal hyperparameters
    X_oversampled, y_oversampled = BorderlineSMOTE(random_state=0).fit_sample(X, y)
    tuned_model = XGBC(objective='binary:logistic', learning_rate=best_learning_rate, n_estimators=best_ntree_limit,
                       max_depth=max_depth, n_jobs=-1, random_state=0)
    tuned_model.fit(X=X_oversampled, y=y_oversampled, eval_metric=['error', 'logloss', 'auc'],
                      eval_set=[(X_oversampled, y_oversampled), (X_test, y_test)],verbose=True)

    # serialize the model and export to local memory
    pickle.dump(tuned_model, open('ASG_predictor.model', 'wb'))
# Out:
# [0]	validation_0-auc:0.951844	validation_1-auc:0.944929
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951844	validation_1-auc:0.944929
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951844	validation_1-auc:0.944929
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951844	validation_1-auc:0.944929
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [11]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [12]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [2]	validation_0-auc:0.951844	validation_1-auc:0.944929
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951844	validation_1-auc:0.944929
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [11]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [1]	validation_0-auc:0.951844	validation_1-auc:0.944929
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951844	validation_1-auc:0.944929
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951844	validation_1-auc:0.944929
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939345	validation_1-auc:0.905961
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939345	validation_1-auc:0.905961
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939345	validation_1-auc:0.905961
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939345	validation_1-auc:0.905961
# [9]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [2]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [3]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [4]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [5]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [6]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [7]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [8]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [9]	validation_0-auc:0.951869	validation_1-auc:0.944688
# [10]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Stopping. Best iteration:
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
#
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [2]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [3]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [4]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [5]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [6]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [7]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [8]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [9]	validation_0-auc:0.939171	validation_1-auc:0.919845
# [10]	validation_0-auc:0.939171	validation_1-auc:0.919845
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939171	validation_1-auc:0.919845
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [2]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [3]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [4]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [5]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [6]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [7]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [8]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [9]	validation_0-auc:0.931162	validation_1-auc:0.91923
# [10]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Stopping. Best iteration:
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
#
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [2]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [3]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [4]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [5]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [6]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [7]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [8]	validation_0-auc:0.939156	validation_1-auc:0.91441
# [9]	validation_0-auc:0.939345	validation_1-auc:0.905961
# [10]	validation_0-auc:0.939156	validation_1-auc:0.91441
# Stopping. Best iteration:
# [0]	validation_0-auc:0.939156	validation_1-auc:0.91441
#
# [0]	validation_0-auc:0.951869	validation_1-auc:0.944688
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# ...
# [77]	validation_0-auc:0.995059	validation_1-auc:0.987707
# [78]	validation_0-auc:0.995068	validation_1-auc:0.987691
# [79]	validation_0-auc:0.995086	validation_1-auc:0.987514
# [80]	validation_0-auc:0.995317	validation_1-auc:0.987635
# [81]	validation_0-auc:0.995486	validation_1-auc:0.987651
# [82]	validation_0-auc:0.99553	validation_1-auc:0.987699
# [83]	validation_0-auc:0.995521	validation_1-auc:0.987828
# [84]	validation_0-auc:0.995563	validation_1-auc:0.987973
# [85]	validation_0-auc:0.995592	validation_1-auc:0.988126
# [86]	validation_0-auc:0.995648	validation_1-auc:0.988182
# [87]	validation_0-auc:0.99567	validation_1-auc:0.988142
# [88]	validation_0-auc:0.995663	validation_1-auc:0.988142
# [89]	validation_0-auc:0.995688	validation_1-auc:0.988158
# [90]	validation_0-auc:0.995773	validation_1-auc:0.988238
# [91]	validation_0-auc:0.995849	validation_1-auc:0.988134
# [92]	validation_0-auc:0.995894	validation_1-auc:0.98819
# [93]	validation_0-auc:0.995958	validation_1-auc:0.988246
# [94]	validation_0-auc:0.995994	validation_1-auc:0.988246
# [95]	validation_0-auc:0.996054	validation_1-auc:0.988206
# [96]	validation_0-auc:0.996041	validation_1-auc:0.988318
# [97]	validation_0-auc:0.996042	validation_1-auc:0.988375
# [98]	validation_0-auc:0.996092	validation_1-auc:0.988495
# [99]	validation_0-auc:0.996115	validation_1-auc:0.988544
# [100]	validation_0-auc:0.996283	validation_1-auc:0.988519
# [101]	validation_0-auc:0.99629	validation_1-auc:0.988391
# [102]	validation_0-auc:0.996321	validation_1-auc:0.988375
# [103]	validation_0-auc:0.99632	validation_1-auc:0.988423
# [104]	validation_0-auc:0.996367	validation_1-auc:0.988463
# [105]	validation_0-auc:0.996441	validation_1-auc:0.988415
# [106]	validation_0-auc:0.996456	validation_1-auc:0.988471
# [107]	validation_0-auc:0.996469	validation_1-auc:0.988527
# [108]	validation_0-auc:0.99649	validation_1-auc:0.988511
# [109]	validation_0-auc:0.996581	validation_1-auc:0.988576
# [110]	validation_0-auc:0.996582	validation_1-auc:0.988503
# [111]	validation_0-auc:0.996559	validation_1-auc:0.988519
# [112]	validation_0-auc:0.996593	validation_1-auc:0.98864
# [113]	validation_0-auc:0.996623	validation_1-auc:0.98868
# [114]	validation_0-auc:0.996663	validation_1-auc:0.98856
# [115]	validation_0-auc:0.996693	validation_1-auc:0.9886
# [116]	validation_0-auc:0.996728	validation_1-auc:0.988536
# [117]	validation_0-auc:0.996846	validation_1-auc:0.988568
# [118]	validation_0-auc:0.996906	validation_1-auc:0.988503
# [119]	validation_0-auc:0.997043	validation_1-auc:0.988503
# [120]	validation_0-auc:0.997123	validation_1-auc:0.988552
# [121]	validation_0-auc:0.997149	validation_1-auc:0.988536
# [122]	validation_0-auc:0.997186	validation_1-auc:0.988511
# [123]	validation_0-auc:0.997279	validation_1-auc:0.988544
# Stopping. Best iteration:
# [113]	validation_0-auc:0.996623	validation_1-auc:0.98868
#
# [0]	validation_0-auc:0.931162	validation_1-auc:0.91923
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.931152	validation_1-auc:0.919214
# [2]	validation_0-auc:0.963028	validation_1-auc:0.936214
# [3]	validation_0-auc:0.964893	validation_1-auc:0.940354
# [4]	validation_0-auc:0.964856	validation_1-auc:0.938867
# [5]	validation_0-auc:0.964991	validation_1-auc:0.940057
# [6]	validation_0-auc:0.97222	validation_1-auc:0.950146
# [7]	validation_0-auc:0.972231	validation_1-auc:0.950158
# [8]	validation_0-auc:0.97224	validation_1-auc:0.950191
# [9]	validation_0-auc:0.973372	validation_1-auc:0.953732
# [10]	validation_0-auc:0.97528	validation_1-auc:0.956506
# [11]	validation_0-auc:0.974	validation_1-auc:0.954186
# [12]	validation_0-auc:0.979667	validation_1-auc:0.963597
# [13]	validation_0-auc:0.980534	validation_1-auc:0.964879
# [14]	validation_0-auc:0.980021	validation_1-auc:0.963838
# [15]	validation_0-auc:0.980646	validation_1-auc:0.96473
# [16]	validation_0-auc:0.981328	validation_1-auc:0.965554
# [17]	validation_0-auc:0.98225	validation_1-auc:0.966447
# [18]	validation_0-auc:0.982736	validation_1-auc:0.967914
# [19]	validation_0-auc:0.982574	validation_1-auc:0.967415
# [20]	validation_0-auc:0.982981	validation_1-auc:0.968388
# [21]	validation_0-auc:0.984645	validation_1-auc:0.970241
# [22]	validation_0-auc:0.985337	validation_1-auc:0.971439
# [23]	validation_0-auc:0.985912	validation_1-auc:0.97203
# [24]	validation_0-auc:0.98631	validation_1-auc:0.972175
# [25]	validation_0-auc:0.987121	validation_1-auc:0.972689
# [26]	validation_0-auc:0.987337	validation_1-auc:0.972915
# [27]	validation_0-auc:0.98789	validation_1-auc:0.975929
# [28]	validation_0-auc:0.988378	validation_1-auc:0.976536
# [29]	validation_0-auc:0.988967	validation_1-auc:0.97691
# [30]	validation_0-auc:0.989187	validation_1-auc:0.976701
# [31]	validation_0-auc:0.989605	validation_1-auc:0.976701
# [32]	validation_0-auc:0.990137	validation_1-auc:0.977176
# [33]	validation_0-auc:0.99021	validation_1-auc:0.977401
# [34]	validation_0-auc:0.990456	validation_1-auc:0.977996
# [35]	validation_0-auc:0.990579	validation_1-auc:0.978072
# [36]	validation_0-auc:0.990726	validation_1-auc:0.978482
# [37]	validation_0-auc:0.990785	validation_1-auc:0.978715
# [38]	validation_0-auc:0.991066	validation_1-auc:0.978603
# [39]	validation_0-auc:0.991318	validation_1-auc:0.979499
# [40]	validation_0-auc:0.991652	validation_1-auc:0.980082
# [41]	validation_0-auc:0.991786	validation_1-auc:0.980267
# [42]	validation_0-auc:0.992044	validation_1-auc:0.980496
# [43]	validation_0-auc:0.992207	validation_1-auc:0.980508
# [44]	validation_0-auc:0.992264	validation_1-auc:0.980733
# [45]	validation_0-auc:0.992402	validation_1-auc:0.980854
# [46]	validation_0-auc:0.992488	validation_1-auc:0.98099
# [47]	validation_0-auc:0.99259	validation_1-auc:0.98136
# [48]	validation_0-auc:0.992763	validation_1-auc:0.981521
# [49]	validation_0-auc:0.99293	validation_1-auc:0.98142
# [50]	validation_0-auc:0.993165	validation_1-auc:0.981766
# [51]	validation_0-auc:0.993372	validation_1-auc:0.982072
# [52]	validation_0-auc:0.993494	validation_1-auc:0.982249
# [53]	validation_0-auc:0.993537	validation_1-auc:0.982128
# [54]	validation_0-auc:0.993619	validation_1-auc:0.982634
# [55]	validation_0-auc:0.993773	validation_1-auc:0.982755
# [56]	validation_0-auc:0.993912	validation_1-auc:0.982731
# [57]	validation_0-auc:0.994233	validation_1-auc:0.982843
# [58]	validation_0-auc:0.994327	validation_1-auc:0.982852
# [59]	validation_0-auc:0.994462	validation_1-auc:0.983109
# [60]	validation_0-auc:0.99453	validation_1-auc:0.983149
# [61]	validation_0-auc:0.99461	validation_1-auc:0.983262
# [62]	validation_0-auc:0.994638	validation_1-auc:0.983262
# [63]	validation_0-auc:0.994651	validation_1-auc:0.983764
# [64]	validation_0-auc:0.994724	validation_1-auc:0.983852
# [65]	validation_0-auc:0.994738	validation_1-auc:0.983732
# [66]	validation_0-auc:0.994782	validation_1-auc:0.983985
# [67]	validation_0-auc:0.994969	validation_1-auc:0.983977
# [68]	validation_0-auc:0.994965	validation_1-auc:0.983961
# [69]	validation_0-auc:0.995173	validation_1-auc:0.984106
# [70]	validation_0-auc:0.995214	validation_1-auc:0.984025
# [71]	validation_0-auc:0.995285	validation_1-auc:0.984202
# [72]	validation_0-auc:0.995322	validation_1-auc:0.984475
# [73]	validation_0-auc:0.995369	validation_1-auc:0.9845
# [74]	validation_0-auc:0.995426	validation_1-auc:0.984564
# [75]	validation_0-auc:0.995467	validation_1-auc:0.984628
# [76]	validation_0-auc:0.99554	validation_1-auc:0.984757
# [77]	validation_0-auc:0.995639	validation_1-auc:0.984934
# [78]	validation_0-auc:0.995679	validation_1-auc:0.985038
# [79]	validation_0-auc:0.995691	validation_1-auc:0.984781
# [80]	validation_0-auc:0.995657	validation_1-auc:0.984837
# [81]	validation_0-auc:0.995698	validation_1-auc:0.985054
# [82]	validation_0-auc:0.995729	validation_1-auc:0.985095
# [83]	validation_0-auc:0.995763	validation_1-auc:0.985159
# [84]	validation_0-auc:0.9958	validation_1-auc:0.985352
# [85]	validation_0-auc:0.995827	validation_1-auc:0.985376
# [86]	validation_0-auc:0.995973	validation_1-auc:0.985472
# [87]	validation_0-auc:0.996084	validation_1-auc:0.985384
# [88]	validation_0-auc:0.996178	validation_1-auc:0.985344
# [89]	validation_0-auc:0.996194	validation_1-auc:0.985352
# [90]	validation_0-auc:0.996216	validation_1-auc:0.985344
# [91]	validation_0-auc:0.996244	validation_1-auc:0.985352
# [92]	validation_0-auc:0.996302	validation_1-auc:0.98548
# [93]	validation_0-auc:0.996297	validation_1-auc:0.985746
# [94]	validation_0-auc:0.996395	validation_1-auc:0.985794
# [95]	validation_0-auc:0.996419	validation_1-auc:0.985939
# [96]	validation_0-auc:0.996423	validation_1-auc:0.985915
# [97]	validation_0-auc:0.996437	validation_1-auc:0.98577
# [98]	validation_0-auc:0.996506	validation_1-auc:0.98573
# [99]	validation_0-auc:0.996511	validation_1-auc:0.985842
# [100]	validation_0-auc:0.996529	validation_1-auc:0.986043
# [101]	validation_0-auc:0.996518	validation_1-auc:0.986011
# [102]	validation_0-auc:0.996573	validation_1-auc:0.985955
# [103]	validation_0-auc:0.996615	validation_1-auc:0.985963
# [104]	validation_0-auc:0.996613	validation_1-auc:0.986244
# [105]	validation_0-auc:0.996626	validation_1-auc:0.986067
# [106]	validation_0-auc:0.996659	validation_1-auc:0.986059
# [107]	validation_0-auc:0.996662	validation_1-auc:0.986083
# [108]	validation_0-auc:0.996682	validation_1-auc:0.986099
# [109]	validation_0-auc:0.996696	validation_1-auc:0.986365
# [110]	validation_0-auc:0.996707	validation_1-auc:0.986333
# [111]	validation_0-auc:0.996715	validation_1-auc:0.9863
# [112]	validation_0-auc:0.996782	validation_1-auc:0.986333
# [113]	validation_0-auc:0.996792	validation_1-auc:0.986317
# [114]	validation_0-auc:0.996803	validation_1-auc:0.986357
# [115]	validation_0-auc:0.996827	validation_1-auc:0.986349
# [116]	validation_0-auc:0.996868	validation_1-auc:0.986349
# [117]	validation_0-auc:0.996869	validation_1-auc:0.986268
# [118]	validation_0-auc:0.996873	validation_1-auc:0.986357
# [119]	validation_0-auc:0.996879	validation_1-auc:0.986534
# [120]	validation_0-auc:0.996903	validation_1-auc:0.986662
# [121]	validation_0-auc:0.996973	validation_1-auc:0.98671
# [122]	validation_0-auc:0.996992	validation_1-auc:0.986743
# [123]	validation_0-auc:0.996999	validation_1-auc:0.986654
# [124]	validation_0-auc:0.997013	validation_1-auc:0.986694
# [125]	validation_0-auc:0.9971	validation_1-auc:0.986654
# [126]	validation_0-auc:0.997147	validation_1-auc:0.986678
# [127]	validation_0-auc:0.997159	validation_1-auc:0.986646
# [128]	validation_0-auc:0.997177	validation_1-auc:0.986574
# [129]	validation_0-auc:0.997193	validation_1-auc:0.98663
# [130]	validation_0-auc:0.997227	validation_1-auc:0.986646
# [131]	validation_0-auc:0.99725	validation_1-auc:0.986614
# [132]	validation_0-auc:0.997244	validation_1-auc:0.986646
# Stopping. Best iteration:
# [122]	validation_0-auc:0.996992	validation_1-auc:0.986743
#
# [0]	validation_0-auc:0.939345	validation_1-auc:0.905961
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.942585	validation_1-auc:0.927141
# [2]	validation_0-auc:0.942588	validation_1-auc:0.927141
# [3]	validation_0-auc:0.942598	validation_1-auc:0.927245
# [4]	validation_0-auc:0.947572	validation_1-auc:0.931816
# [5]	validation_0-auc:0.963575	validation_1-auc:0.953165
# [6]	validation_0-auc:0.963438	validation_1-auc:0.953085
# [7]	validation_0-auc:0.974116	validation_1-auc:0.967705
# [8]	validation_0-auc:0.975069	validation_1-auc:0.968517
# [9]	validation_0-auc:0.974793	validation_1-auc:0.968384
# [10]	validation_0-auc:0.97773	validation_1-auc:0.972625
# [11]	validation_0-auc:0.980419	validation_1-auc:0.974961
# [12]	validation_0-auc:0.981621	validation_1-auc:0.974647
# [13]	validation_0-auc:0.981665	validation_1-auc:0.974325
# [14]	validation_0-auc:0.9819	validation_1-auc:0.976239
# [15]	validation_0-auc:0.982285	validation_1-auc:0.976492
# [16]	validation_0-auc:0.982557	validation_1-auc:0.976191
# [17]	validation_0-auc:0.983028	validation_1-auc:0.97648
# [18]	validation_0-auc:0.983249	validation_1-auc:0.975966
# [19]	validation_0-auc:0.983661	validation_1-auc:0.976339
# [20]	validation_0-auc:0.984285	validation_1-auc:0.977127
# [21]	validation_0-auc:0.984499	validation_1-auc:0.977405
# [22]	validation_0-auc:0.985123	validation_1-auc:0.978
# [23]	validation_0-auc:0.985644	validation_1-auc:0.977742
# [24]	validation_0-auc:0.986182	validation_1-auc:0.977927
# [25]	validation_0-auc:0.986237	validation_1-auc:0.978012
# [26]	validation_0-auc:0.987238	validation_1-auc:0.978229
# [27]	validation_0-auc:0.987168	validation_1-auc:0.977634
# [28]	validation_0-auc:0.98799	validation_1-auc:0.97845
# [29]	validation_0-auc:0.988804	validation_1-auc:0.978932
# [30]	validation_0-auc:0.989028	validation_1-auc:0.979189
# [31]	validation_0-auc:0.989866	validation_1-auc:0.979515
# [32]	validation_0-auc:0.990169	validation_1-auc:0.979571
# [33]	validation_0-auc:0.990609	validation_1-auc:0.979973
# [34]	validation_0-auc:0.99079	validation_1-auc:0.980464
# [35]	validation_0-auc:0.990892	validation_1-auc:0.981207
# [36]	validation_0-auc:0.991131	validation_1-auc:0.981059
# [37]	validation_0-auc:0.99134	validation_1-auc:0.981115
# [38]	validation_0-auc:0.991498	validation_1-auc:0.981364
# [39]	validation_0-auc:0.991664	validation_1-auc:0.981139
# [40]	validation_0-auc:0.99211	validation_1-auc:0.981364
# [41]	validation_0-auc:0.992279	validation_1-auc:0.981388
# [42]	validation_0-auc:0.992304	validation_1-auc:0.981621
# [43]	validation_0-auc:0.992339	validation_1-auc:0.981927
# [44]	validation_0-auc:0.992531	validation_1-auc:0.98177
# [45]	validation_0-auc:0.992653	validation_1-auc:0.982052
# [46]	validation_0-auc:0.992864	validation_1-auc:0.982244
# [47]	validation_0-auc:0.993036	validation_1-auc:0.982622
# [48]	validation_0-auc:0.993331	validation_1-auc:0.982872
# [49]	validation_0-auc:0.993546	validation_1-auc:0.983032
# [50]	validation_0-auc:0.993593	validation_1-auc:0.983193
# [51]	validation_0-auc:0.993587	validation_1-auc:0.983434
# [52]	validation_0-auc:0.993605	validation_1-auc:0.983298
# [53]	validation_0-auc:0.993639	validation_1-auc:0.983153
# [54]	validation_0-auc:0.993728	validation_1-auc:0.983177
# [55]	validation_0-auc:0.993826	validation_1-auc:0.983137
# [56]	validation_0-auc:0.994021	validation_1-auc:0.983169
# [57]	validation_0-auc:0.994138	validation_1-auc:0.983386
# [58]	validation_0-auc:0.994297	validation_1-auc:0.983603
# [59]	validation_0-auc:0.994418	validation_1-auc:0.983676
# [60]	validation_0-auc:0.994533	validation_1-auc:0.983595
# [61]	validation_0-auc:0.994691	validation_1-auc:0.983539
# [62]	validation_0-auc:0.994797	validation_1-auc:0.983732
# [63]	validation_0-auc:0.994933	validation_1-auc:0.983724
# [64]	validation_0-auc:0.994966	validation_1-auc:0.983901
# [65]	validation_0-auc:0.994991	validation_1-auc:0.984069
# [66]	validation_0-auc:0.995132	validation_1-auc:0.984069
# [67]	validation_0-auc:0.995184	validation_1-auc:0.983901
# [68]	validation_0-auc:0.995222	validation_1-auc:0.984142
# [69]	validation_0-auc:0.995294	validation_1-auc:0.984134
# [70]	validation_0-auc:0.995511	validation_1-auc:0.984182
# [71]	validation_0-auc:0.995614	validation_1-auc:0.984174
# [72]	validation_0-auc:0.995663	validation_1-auc:0.984182
# [73]	validation_0-auc:0.995732	validation_1-auc:0.984234
# [74]	validation_0-auc:0.995757	validation_1-auc:0.984202
# [75]	validation_0-auc:0.995818	validation_1-auc:0.98417
# [76]	validation_0-auc:0.995865	validation_1-auc:0.984202
# [77]	validation_0-auc:0.99589	validation_1-auc:0.984098
# [78]	validation_0-auc:0.995946	validation_1-auc:0.984307
# [79]	validation_0-auc:0.995981	validation_1-auc:0.984443
# [80]	validation_0-auc:0.996052	validation_1-auc:0.984564
# [81]	validation_0-auc:0.996062	validation_1-auc:0.984564
# [82]	validation_0-auc:0.99611	validation_1-auc:0.984451
# [83]	validation_0-auc:0.996123	validation_1-auc:0.984242
# [84]	validation_0-auc:0.996194	validation_1-auc:0.984299
# [85]	validation_0-auc:0.996198	validation_1-auc:0.984331
# [86]	validation_0-auc:0.996235	validation_1-auc:0.984419
# [87]	validation_0-auc:0.996278	validation_1-auc:0.984419
# [88]	validation_0-auc:0.996416	validation_1-auc:0.984234
# [89]	validation_0-auc:0.996424	validation_1-auc:0.984154
# [90]	validation_0-auc:0.996489	validation_1-auc:0.984226
# Stopping. Best iteration:
# [80]	validation_0-auc:0.996052	validation_1-auc:0.984564

# %%
tuned_model = pickle.load(open('ASG_predictor.model', 'rb'))

# run the tuned model on the test set and get all-star prediction probabilities
y_test_proba = [prob[1] for prob in tuned_model.predict_proba(X_test)]

# shows model performance progress during training and how it fares with the test set
def show_model_evaluations():
    
    plt.style.use('dark_background')

    results = tuned_model.evals_result()
    epochs = len(results['validation_0']['auc'])
    x_axis = range(0, epochs)

    fig, ax = plt.subplots(figsize=(8,8))
    ax.plot(x_axis, results['validation_0']['auc'], label='Train')
    ax.plot(x_axis, results['validation_1']['auc'], label='Test')
    plt.title('XGBoost AUC ({} epochs)'.format(epochs))
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    ax.legend()
    plt.savefig('./Plots/AUC-training.png')
    plt.show()

    fig, ax = plt.subplots(figsize=(8,8))
    ax.plot(x_axis, results['validation_0']['error'], label='Train')
    ax.plot(x_axis, results['validation_1']['error'], label='Test')
    plt.title('XGBoost Error% ({} epochs)'.format(epochs))
    plt.xlabel('Epoch')
    plt.ylabel('Error%')
    ax.legend()
    plt.savefig('./Plots/error-training.png')
    plt.show()

    fig, ax = plt.subplots(figsize=(8,8))
    ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
    ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
    plt.title('XGBoost Logarithmic Loss ({} epochs)'.format(epochs))
    plt.xlabel('Epoch')
    plt.ylabel('Log. Loss')
    ax.legend()
    plt.savefig('./Plots/logloss-training.png')
    plt.show()
    
    plt.style.use('default')
    plt.style.use('ggplot')

    fig, ax = plt.subplots(figsize=(8,8))
    fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)
    no_skill = [0] * len(y_test)
    fpr_ns, tpr_ns, thresholds_ns = roc_curve(y_test, no_skill)
    ax.plot(fpr, tpr, label='XGBoost')
    ax.plot(fpr_ns, tpr_ns, linestyle='--', label='No Skill')
    plt.title('XGBoost Receiver Operating Characteristic\n(AUC = {:.4f})'.format(roc_auc_score(y_test, y_test_proba)))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    ax.legend()
    plt.savefig('./Plots/ROCAUC.png')
    plt.show()

    plt.style.use('default')
    plt.style.use('seaborn-deep')

    cmap = matplotlib.colors.LinearSegmentedColormap.from_list('', ['#FFFFFF', '#264d73'])
    fig, ax = plt.subplots(figsize=(8,8))
    plot_confusion_matrix(tuned_model, X_test, y_test, cmap=cmap, display_labels=['Not AS', 'All Star'], normalize='true', ax=ax)
    plt.title('Normalized confusion matrix\n')
    plt.savefig('./Plots/confusion.png')
    plt.show()


def show_model_interpretation():
    
    # uses SHAP values to "explain" the model robustly
    # SHAP provides model inteprtation metrics that are accurate and consistent (unlike gain, cover or weight)
    explainer = shap.TreeExplainer(tuned_model)
    shap_values = explainer.shap_values(X)
    
    plt.style.use('seaborn-deep')

    shap.summary_plot(shap_values, X, plot_type='dot', plot_size=(12,8), show=False)
    plt.subplots_adjust(left=0.3)
    plt.title('Model SHAP Details')
    plt.savefig('./Plots/SHAP-Details.png')
    plt.show()

    shap.summary_plot(shap_values, X, plot_type='bar', color='#264d73', plot_size=(12,8), show=False)
    plt.subplots_adjust(left=0.22)
    plt.title('Model SHAP Summary')
    plt.savefig('./Plots/SHAP-Summary.png')
    plt.show()

    partial_dependence_features = ['PIE', 'Team Conference Rank', 'Play Pct.']
    for i, feature in enumerate(partial_dependence_features):
        pdp_feature = pdp.pdp_isolate(model=tuned_model, dataset=X_test, model_features=X_test.columns.tolist(), feature=feature)
        fig, ax = pdp.pdp_plot(pdp_feature, feature, figsize=(10,8))
        plt.savefig('./Plots/indiviual-pdp-{}.png'.format(i+1))
        plt.show()
    
    interaction_features = (['PIE', 'Team Conference Rank'], ['PIE', 'Play Pct.'])
    for i, pair in enumerate(interaction_features):
        interaction = pdp.pdp_interact(model=tuned_model, dataset=X_test, model_features=X_test.columns.tolist(), features=pair)
        fig, ax = pdp.pdp_interact_plot(pdp_interact_out=interaction, feature_names=pair, plot_type='contour', figsize=(10,8))
        plt.savefig('./Plots/interaction-pdp-{}.png'.format(i+1))
        plt.show()

def show_classification_metrics():

    # range of classification thresholds to consider
    thresholds = np.arange(0.1, 1, 0.0025)

    highest_f1_score = -float('inf')
    optimal_threshold = thresholds[0]
    for threshold in thresholds:
        y_pred = [0 if prob < threshold else 1 for prob in y_test_proba]
        curr_f1_score = f1_score(y_test, y_pred)
        if curr_f1_score > highest_f1_score:
            highest_f1_score = curr_f1_score
            optimal_threshold = threshold

    # our binary-forced predictions based upon our F1-score-optimized threshhold
    y_pred = [0 if prob < optimal_threshold else 1 for prob in y_test_proba]

    metrics = [
        'Accuracy',
        'Precision',
        'Recall',
        'F1 Score',
        'Log. Loss',
        'ROC AUC'
    ]

    scores = [
        accuracy_score(y_test, y_pred),
        precision_score(y_test, y_pred),
        recall_score(y_test, y_pred),
        f1_score(y_test, y_pred),
        log_loss(y_test, y_test_proba),
        roc_auc_score(y_test, y_test_proba)
    ]

    df_classification_metrics = pd.DataFrame({'Metric' : metrics, 'Score' : scores}).set_index('Metric')

    return df_classification_metrics

# %% [markdown]
# ## Model Learning Evaluation and Performance

# %%
show_model_evaluations()

# %% [markdown]
# ## Model Interpretation using SHAP Values and Partial Dependance

# %%
show_model_interpretation()

# %% [markdown]
# ## Model Classification Metrics

# %%
show_classification_metrics()
# Out:
#               Score
# Metric
# Accuracy   0.973799
# Precision  0.773399
# Recall     0.830688
# F1 Score   0.801020
# Log. Loss  0.112136
# ROC AUC    0.989650

# %% [markdown]
# ## Model Application to Current Players

# %%
# the following section applies the tuned model to all the active players in the current season
# the classifiction schema here takes the top 12 prediction probabilities from each
# conference, slightly different than our fixed threshold

df_to_predict['AS Prob.'] = [prob[1] for prob in tuned_model.predict_proba(df_to_predict)]

#saving this for later to do some case-by-case analysis
df_predictions = df_to_predict.copy().join(names_and_teams)

df_to_predict = df_to_predict.join(names_and_teams)[['PLAYER', 'TEAM', 'AS Prob.']]

eastern_conference = set(['ATL', 'BOS', 'BKN', 'CHA', 'CHI', 'CLE', 'DET', 'IND', 'MIA',
                          'MIL', 'NYK', 'ORL', 'PHI', 'TOR', 'WAS'])
df_to_predict['Conf.'] = df_to_predict['TEAM'].map(lambda x : 'East' if x in eastern_conference else 'West')

df_east = df_to_predict[df_to_predict['Conf.'] == 'East'].sort_values('AS Prob.', ascending=False).reset_index(drop=True)
df_west = df_to_predict[df_to_predict['Conf.'] == 'West'].sort_values('AS Prob.', ascending=False).reset_index(drop=True)

for df in [df_east, df_west]:
    df['Model Prediction'] = df.index.map(lambda x : 'Yes' if x < 12 else 'No')

df_east = df_east[['PLAYER', 'TEAM', 'Conf.', 'AS Prob.', 'Model Prediction']]
df_west = df_west[['PLAYER', 'TEAM', 'Conf.', 'AS Prob.', 'Model Prediction']]

summary_conf_size = 25

df_results_summary = pd.concat([df_east.head(summary_conf_size), df_west.head(summary_conf_size)]).set_index('PLAYER')
df_results_full = pd.concat([df_east, df_west]).set_index('PLAYER').sort_values('AS Prob.', ascending=False)

df_results_summary.to_csv('{}_NBA_ASG_predictor_results_summary.csv'.format(prediction_year))
df_results_full.to_csv('{}_NBA_ASG_predictor_results_full.csv'.format(prediction_year))

# %% [markdown]
# ## Predictions for 2020 All-Star Game Selection

# %% [markdown]
# ### Eastern Conference

# %%
df_east.head(summary_conf_size).set_index('PLAYER')
# Out:
#                       TEAM Conf.  AS Prob. Model Prediction
# PLAYER
# Giannis Antetokounmpo  MIL  East  0.989731              Yes
# Jimmy Butler           MIA  East  0.980395              Yes
# Jayson Tatum           BOS  East  0.962130              Yes
# Khris Middleton        MIL  East  0.960142              Yes
# Pascal Siakam          TOR  East  0.949181              Yes
# Kemba Walker           BOS  East  0.941882              Yes
# Bam Adebayo            MIA  East  0.908825              Yes
# Joel Embiid            PHI  East  0.907902              Yes
# Kyle Lowry             TOR  East  0.907605              Yes
# Domantas Sabonis       IND  East  0.904676              Yes
# Ben Simmons            PHI  East  0.902075              Yes
# Zach LaVine            CHI  East  0.894512              Yes
# Tobias Harris          PHI  East  0.861565               No
# Jaylen Brown           BOS  East  0.859343               No
# Bradley Beal           WAS  East  0.856452               No
# Fred VanVleet          TOR  East  0.823303               No
# Eric Bledsoe           MIL  East  0.766623               No
# Kyrie Irving           BKN  East  0.733931               No
# Trae Young             ATL  East  0.706847               No
# Nikola Vucevic         ORL  East  0.704834               No
# Spencer Dinwiddie      BKN  East  0.701217               No
# Andre Drummond         CLE  East  0.675826               No
# Al Horford             PHI  East  0.421246               No
# Kevin Love             CLE  East  0.417402               No
# Julius Randle          NYK  East  0.415914               No

# %% [markdown]
# ### Western Conference

# %%
df_west.head(summary_conf_size).set_index('PLAYER')
# Out:
#                         TEAM Conf.  AS Prob. Model Prediction
# PLAYER
# LeBron James             LAL  West  0.991507              Yes
# James Harden             HOU  West  0.990176              Yes
# Anthony Davis            LAL  West  0.988322              Yes
# Kawhi Leonard            LAC  West  0.979543              Yes
# Russell Westbrook        HOU  West  0.972067              Yes
# Nikola Jokic             DEN  West  0.968638              Yes
# Damian Lillard           POR  West  0.965867              Yes
# Luka Doncic              DAL  West  0.962452              Yes
# Donovan Mitchell         UTA  West  0.960731              Yes
# Paul George              LAC  West  0.953716              Yes
# Rudy Gobert              UTA  West  0.921372              Yes
# Brandon Ingram           NOP  West  0.899433              Yes
# Devin Booker             PHX  West  0.844558               No
# DeMar DeRozan            SAS  West  0.837638               No
# Lou Williams             LAC  West  0.809017               No
# Karl-Anthony Towns       MIN  West  0.794761               No
# Shai Gilgeous-Alexander  OKC  West  0.765328               No
# Jamal Murray             DEN  West  0.731261               No
# Montrezl Harrell         LAC  West  0.725298               No
# Dennis Schroder          OKC  West  0.707062               No
# LaMarcus Aldridge        SAS  West  0.614188               No
# Will Barton              DEN  West  0.587066               No
# Chris Paul               OKC  West  0.548607               No
# D'Angelo Russell         MIN  West  0.504361               No
# Jrue Holiday             NOP  West  0.440782               No

# %% [markdown]
# ## Investigating Edge Cases

# %%
players_to_investigate = ['Zach LaVine',
                          'Trae Young',
                          'Paul George',
                          'Chris Paul',
                          'Devin Booker',
                          'Kyle Lowry',
                          'Rudy Gobert',
                          'Jaylen Brown',
                          'Bradley Beal',
                          'Ben Simmons']
df_investigation = df_predictions[df_predictions['PLAYER'].isin(players_to_investigate)]
investigation_names = list(df_investigation['PLAYER'])
df_investigation = df_investigation[features]
explainer = shap.TreeExplainer(tuned_model)

shap.initjs()
for i in range(len(df_investigation)):
    player_shap_values = explainer.shap_values(df_investigation.iloc[i])
    #text overlapping with Chris Paul since his predicted value sits close to the baseline
    out_name = '' if investigation_names[i] == 'Chris Paul' else 'Pred.'
    print(investigation_names[i])
    display(shap.force_plot(explainer.expected_value, player_shap_values, df_investigation.iloc[i],
                           link='logit', out_names=out_name, feature_names=feature_short_labels))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# Trae Young
# <div id='i7O5B8TPSBB2YC8RNSQY0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 0.8801186084747314, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 2.1764769554138184, "value": 0.29112662013958124}, "1": {"effect": -0.029908377677202225, "value": 0.04685942173479562}, "2": {"effect": 0.18916085362434387, "value": 0.08574277168494517}, "3": {"effect": -0.9461851119995117, "value": 0.0009970089730807579}, "4": {"effect": -0.745829701423645, "value": 0.001}, "5": {"effect": 0.033314477652311325, "value": 33.8}, "6": {"effect": 1.4780219793319702, "value": 16.4}, "7": {"effect": 0.027714526280760765, "value": 0.9090909090909091}, "8": {"effect": -1.1272704601287842, "value": 15.0}, "9": {"effect": -0.171591117978096, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i7O5B8TPSBB2YC8RNSQY0')
#   );
# </script>
# Bradley Beal
# <div id='iRG79X7BG2HV4OQB50HB5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 1.7861268520355225, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 2.3446080684661865, "value": 0.2711864406779661}, "1": {"effect": -0.029908377677202225, "value": 0.0448654037886341}, "2": {"effect": 0.20795249938964844, "value": 0.06281156530408774}, "3": {"effect": -0.29672569036483765, "value": 0.002991026919242273}, "4": {"effect": -0.6087133884429932, "value": -0.001}, "5": {"effect": 0.033314477652311325, "value": 31.8}, "6": {"effect": 0.7337247133255005, "value": 12.6}, "7": {"effect": -0.015622833743691444, "value": 0.8333333333333334}, "8": {"effect": -0.6558039784431458, "value": 11.0}, "9": {"effect": 0.07708658277988434, "value": 2.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRG79X7BG2HV4OQB50HB5')
#   );
# </script>
# Devin Booker
# <div id='i3RQT8KQU91UZ7M5ZSVK2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 1.6925413608551025, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 2.3319549560546875, "value": 0.2671984047856431}, "1": {"effect": -0.09588634967803955, "value": 0.040877367896311065}, "2": {"effect": 0.20795249938964844, "value": 0.0638085742771685}, "3": {"effect": -0.3226565718650818, "value": 0.0019940179461615157}, "4": {"effect": -0.4753652811050415, "value": 0.002}, "5": {"effect": 0.033314477652311325, "value": 28.9}, "6": {"effect": 0.7413033246994019, "value": 14.1}, "7": {"effect": 0.12557148933410645, "value": 0.9302325581395349}, "8": {"effect": -0.6949579119682312, "value": 11.0}, "9": {"effect": -0.15490399301052094, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3RQT8KQU91UZ7M5ZSVK2')
#   );
# </script>
# Zach LaVine
# <div id='iGT2WSGTZ9RX6KQDSIT57'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 2.137680768966675, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 2.322150468826294, "value": 0.24925224327018944}, "1": {"effect": -0.029908377677202225, "value": 0.04685942173479562}, "2": {"effect": 0.26977190375328064, "value": 0.038883349950149554}, "3": {"effect": 0.10694380104541779, "value": 0.004985044865403789}, "4": {"effect": -0.4693361222743988, "value": 0.002}, "5": {"effect": 0.033314477652311325, "value": 30.8}, "6": {"effect": 0.710311770439148, "value": 13.3}, "7": {"effect": 0.019277039915323257, "value": 1.0}, "8": {"effect": -0.6825246214866638, "value": 10.0}, "9": {"effect": -0.13853394985198975, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iGT2WSGTZ9RX6KQDSIT57')
#   );
# </script>
# Paul George
# <div id='i9OL6G8UIJH7YVJ551MCV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 3.0255672931671143, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 2.018336296081543, "value": 0.23429710867397807}, "1": {"effect": -0.014375967904925346, "value": 0.05982053838484547}, "2": {"effect": 0.26977190375328064, "value": 0.036889332003988036}, "3": {"effect": 0.08287816494703293, "value": 0.004985044865403789}, "4": {"effect": 0.11616738885641098, "value": 0.003}, "5": {"effect": 0.033314477652311325, "value": 30.5}, "6": {"effect": 1.2079441547393799, "value": 14.9}, "7": {"effect": -1.2440441846847534, "value": 0.5909090909090909}, "8": {"effect": 0.19583754241466522, "value": 2.0}, "9": {"effect": 0.3635227382183075, "value": 6.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9OL6G8UIJH7YVJ551MCV')
#   );
# </script>
# Kyle Lowry
# <div id='iEP3CV93D2D9GKDD45QCQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 2.2847392559051514, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 1.0379208326339722, "value": 0.20039880358923232}, "1": {"effect": -0.021220393478870392, "value": 0.0448654037886341}, "2": {"effect": 0.2675328552722931, "value": 0.07577268195413758}, "3": {"effect": -0.0341527983546257, "value": 0.0039880358923230315}, "4": {"effect": 0.12037692219018936, "value": 0.003}, "5": {"effect": -0.02019132487475872, "value": 22.5}, "6": {"effect": 1.0247679948806763, "value": 12.2}, "7": {"effect": -0.8170785903930664, "value": 0.7441860465116279}, "8": {"effect": 0.22670237720012665, "value": 3.0}, "9": {"effect": 0.5038669109344482, "value": 5.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iEP3CV93D2D9GKDD45QCQ')
#   );
# </script>
# Jaylen Brown
# <div id='iHI6I9WU3AIMGJMQMIEDG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 1.8098444938659668, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": 0.7810184359550476, "value": 0.19940179461615154}, "1": {"effect": -0.0391228161752224, "value": 0.06779661016949153}, "2": {"effect": -0.01926545798778534, "value": 0.023928215353938184}, "3": {"effect": -0.3275887072086334, "value": 0.002991026919242273}, "4": {"effect": 0.11819728463888168, "value": 0.003}, "5": {"effect": -0.02019132487475872, "value": 24.1}, "6": {"effect": 1.2239238023757935, "value": 12.1}, "7": {"effect": -0.03845799341797829, "value": 0.8571428571428571}, "8": {"effect": 0.3162461519241333, "value": 4.0}, "9": {"effect": -0.18112964928150177, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iHI6I9WU3AIMGJMQMIEDG')
#   );
# </script>
# Chris Paul
# <div id='iSAZJ2VLHD06F111LZV2R'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": [""], "baseValue": -0.0037852900568395853, "outValue": 0.19504620134830475, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": -0.8046758770942688, "value": 0.1694915254237288}, "1": {"effect": -0.09295471012592316, "value": 0.049850448654037885}, "2": {"effect": 0.17551538348197937, "value": 0.0638085742771685}, "3": {"effect": -0.6381645202636719, "value": 0.0009970089730807579}, "4": {"effect": -0.7332336902618408, "value": 0.002}, "5": {"effect": -0.02019132487475872, "value": 21.7}, "6": {"effect": 1.707754135131836, "value": 14.8}, "7": {"effect": 0.09887368232011795, "value": 1.0}, "8": {"effect": -0.10833960771560669, "value": 7.0}, "9": {"effect": 0.6142479181289673, "value": 9.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iSAZJ2VLHD06F111LZV2R')
#   );
# </script>
# Ben Simmons
# <div id='iZYMG4HZ60XZOC8QAC5ML'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 2.2204954624176025, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": -0.6569547653198242, "value": 0.15952143569292124}, "1": {"effect": 0.27111396193504333, "value": 0.07776669990029911}, "2": {"effect": 0.26977190375328064, "value": 0.0847457627118644}, "3": {"effect": 0.08964571356773376, "value": 0.006979062811565304}, "4": {"effect": 0.29309844970703125, "value": 0.003}, "5": {"effect": -0.02019132487475872, "value": 19.8}, "6": {"effect": 1.5601718425750732, "value": 14.3}, "7": {"effect": 0.18974871933460236, "value": 0.9555555555555556}, "8": {"effect": 0.1101449728012085, "value": 5.0}, "9": {"effect": 0.11773146688938141, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZYMG4HZ60XZOC8QAC5ML')
#   );
# </script>
# Rudy Gobert
# <div id='iBTDVNHDO25Y7PKCT0A79'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["Pred."], "baseValue": -0.0037852900568395853, "outValue": 2.4611384868621826, "link": "logit", "featureNames": ["PTS", "REB", "AST", "BLK", "DEFWS", "USG%", "PIE", "Play%", "Team", "ASG's"], "features": {"0": {"effect": -0.7199004292488098, "value": 0.1535393818544367}, "1": {"effect": 0.4770464599132538, "value": 0.14456630109670987}, "2": {"effect": -0.3854934275150299, "value": 0.01694915254237288}, "3": {"effect": 0.22485719621181488, "value": 0.018943170488534396}, "4": {"effect": 0.7953597903251648, "value": 0.004}, "5": {"effect": -0.009399637579917908, "value": 16.6}, "6": {"effect": 1.8426016569137573, "value": 16.1}, "7": {"effect": 0.19327279925346375, "value": 0.9534883720930233}, "8": {"effect": 0.2157782018184662, "value": 3.0}, "9": {"effect": -0.16919869184494019, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iBTDVNHDO25Y7PKCT0A79')
#   );
# </script>
